# %% [markdown]
# <a href="https://colab.research.google.com/github/evelynda1985/Python/blob/main/Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#  We have 2 variables glass1 and glass2.
#  glass1 contains milk and glass2 contains juice.
#  Write 3 lines of code to switch the contents of the variables.
#  You are not allowed to type the words "milk" or "juice".
#  You are only allowed to use variables to solve this exercise.

# %%
glass1 = "milk"
glass2 = "juice"

new_glass = glass1
glass1 = glass2
glass2 = new_glass
