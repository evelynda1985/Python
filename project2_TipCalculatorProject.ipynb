# %% [markdown]
# <a href="https://colab.research.google.com/github/evelynda1985/Python/blob/main/project2_TipCalculatorProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to the tip calculator!")
bill = float(input("What was the total bill? $"))
tip = int(input("What percentage tip would you like to give? 10 12 15 "))
people = int(input("How many people to split the bill? "))

#Note print(150 * 0.12 + 150) == print(150 * 1.12)

tip_calculation = 1 + (tip / 100)
amount_per_person = round((bill * tip_calculation) / people,2)
print(f"Each person should pay {amount_per_person}")
# Out:
# Welcome to the tip calculator!
# What was the total bill? $135
# What percentage tip would you like to give? 10 12 15 15
# How many people to split the bill? 6
# Each person should pay 25.88
