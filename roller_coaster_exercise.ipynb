# %% [markdown]
# <a href="https://colab.research.google.com/github/evelynda1985/Python/blob/main/roller_coaster_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Roller coaster ejercise
print("Welcome to the rollercoaster!")
height = int(input("What is your height in cm? "))
bill = 0

if height >= 120:
    print("You can ride the rollercoaster")
    age = int(input("What is your age? "))
    if age <= 12:
        print("Child tickets are $5.")
        bill = 5
    elif age <= 18:
        print("Youth tickets are $7.")
        bill = 7
    else:
        print("Adult tickets are  $12. ")
        bill = 12
    wants_photo = input("Would you like to have a photo take? Type y for Yes or n for No ")
    if wants_photo == "y":
        #Add $3 to their bill
        bill += 3
        print(f"Your bill is ${bill}")
    else:
        print(f"Your bill is ${bill}")
else:
    print("Sorry you have to grow taller before you can ride.")
# Out:
# Welcome to the rollercoaster!
# What is your height in cm? 180
# You can ride the rollercoaster
# What is your age? 34
# Adult tickets are  $12.
# Would you like to have a photo take? Type y for Yes or n for No y
# Your bill is $15
